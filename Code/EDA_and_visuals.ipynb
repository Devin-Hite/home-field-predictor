# %% [markdown]
# # EDA and Visuals

# %%
# Imports

import pandas as pd
import matplotlib.pyplot as plt

# %%
# Reading in data from stored csv files

df_13_14 = pd.read_csv(r'C:\Users\Dask\Documents\Code\dsi\capstone\capstone\Data\home_away_data\13_14.csv')
df_14_15 = pd.read_csv(r'C:\Users\Dask\Documents\Code\dsi\capstone\capstone\Data\home_away_data\14_15.csv')
df_15_16 = pd.read_csv(r'C:\Users\Dask\Documents\Code\dsi\capstone\capstone\Data\home_away_data\15_16.csv')
df_16_17 = pd.read_csv(r'C:\Users\Dask\Documents\Code\dsi\capstone\capstone\Data\home_away_data\16_17.csv')
df_17_18 = pd.read_csv(r'C:\Users\Dask\Documents\Code\dsi\capstone\capstone\Data\home_away_data\17_18.csv')
df_18_19 = pd.read_csv(r'C:\Users\Dask\Documents\Code\dsi\capstone\capstone\Data\home_away_data\18_19.csv')
df_19_20 = pd.read_csv(r'C:\Users\Dask\Documents\Code\dsi\capstone\capstone\Data\home_away_data\19_20.csv')
df_20_21 = pd.read_csv(r'C:\Users\Dask\Documents\Code\dsi\capstone\capstone\Data\home_away_data\20_21.csv')
df_21_22 = pd.read_csv(r'C:\Users\Dask\Documents\Code\dsi\capstone\capstone\Data\home_away_data\21_22.csv')
combined_ha = pd.read_csv(r'C:\Users\Dask\Documents\Code\dsi\capstone\capstone\Data\home_away_data\combined_ha.csv')

# %% [markdown]
# ### Performance at home and away for first and last place teams in the English Premier League

# %%
# Creating index of years of data in posession

index = [
    'First 2013',
    'Last 2013',
    'First 2014',
    'Last 2014',
    'First 2015',
    'Last 2015',
    'First 2016',
    'Last 2016',
    'First 2017',
    'Last 2017',
    'First 2018',
    'Last 2018',
    'First 2019',
    'Last 2019',
    'First 2020',
    'Last 2020',
    'First 2021',
    'Last 2021'
]

# %%
# Manually creating a y-axis for home-wins achieved by first and last place team each year

min_max_hw = pd.Series([18, 10, 19, 11, 18, 7, 17, 8, 18, 12, 18, 5, 19, 7, 15, 6, 11, 5], 
index = [
    'First 2013',
    'Last 2013',
    'First 2014',
    'Last 2014',
    'First 2015',
    'Last 2015',
    'First 2016',
    'Last 2016',
    'First 2017',
    'Last 2017',
    'First 2018',
    'Last 2018',
    'First 2019',
    'Last 2019',
    'First 2020',
    'Last 2020',
    'First 2021',
    'Last 2021'
])

# %%
# Manually creating a y-axis for away-wins achieved by first and last place team each year

min_max_aw = pd.Series([14, 6, 16, 3, 17, 4, 16, 4, 18, 7, 16, 5, 16, 4, 17, 3, 13, 4], 
index = [
    'First 2013',
    'Last 2013',
    'First 2014',
    'Last 2014',
    'First 2015',
    'Last 2015',
    'First 2016',
    'Last 2016',
    'First 2017',
    'Last 2017',
    'First 2018',
    'Last 2018',
    'First 2019',
    'Last 2019',
    'First 2020',
    'Last 2020',
    'First 2021',
    'Last 2021'
])

# %%
# Bar chart of home versus away wins for first and last place teams each year

plt.figure(figsize=(14,10), dpi = 100)
plt.bar(index, min_max_hw, color = 'black', label = 'HomeWins')
plt.bar(index, min_max_aw, alpha = 0.5, color = 'red', label = 'AwayWins')
plt.legend()
plt.xticks(rotation=90)
plt.yticks(range(0, 20, 1))
plt.title('Home and Away games undefeated by first and last place in the league each year', fontsize = 18)
plt.xlabel('Year', fontsize = 14)
plt.ylabel('Home/Away games undefeated', fontsize = 14)

plt.savefig(r'C:\Users\Dask\Documents\Code\dsi\capstone\capstone\Figures\league_games_hist.jpg');

# %%
# Manually creating a y-axis for goals scored at home by the first and last place team each year

min_max_goalsh = pd.Series([63, 20, 36, 23, 35, 14, 55, 16, 61, 21, 57, 10, 52, 19, 43, 12, 36, 8], 
index = [
    'First 2013',
    'Last 2013',
    'First 2014',
    'Last 2014',
    'First 2015',
    'Last 2015',
    'First 2016',
    'Last 2016',
    'First 2017',
    'Last 2017',
    'First 2018',
    'Last 2018',
    'First 2019',
    'Last 2019',
    'First 2020',
    'Last 2020',
    'First 2021',
    'Last 2021'
])

# %%
# Manually creating a y-axis for goals scored away by the first and last place team each year

min_max_goalsa = pd.Series([39, 12, 37, 19, 33, 13, 30, 13, 45, 10, 38, 12, 33, 7, 40, 8, 28, 7], 
index = [
    'First 2013',
    'Last 2013',
    'First 2014',
    'Last 2014',
    'First 2015',
    'Last 2015',
    'First 2016',
    'Last 2016',
    'First 2017',
    'Last 2017',
    'First 2018',
    'Last 2018',
    'First 2019',
    'Last 2019',
    'First 2020',
    'Last 2020',
    'First 2021',
    'Last 2021'
])

# %%
# Bar chart of home versus away goals scored by the first and last place teams each year

plt.figure(figsize=(14,10), dpi = 100)
plt.bar(index, min_max_goalsh, color = 'blue', label = 'Home Goals')
plt.bar(index, min_max_goalsa, alpha = 0.5, color = 'red', label = 'Away Goals')
plt.legend()
plt.xticks(rotation=90)
plt.yticks(range(0, 66, 5))
plt.title('Goals scored at home versus away by first and last place in the league each year', fontsize = 18)
plt.xlabel('Year', fontsize = 14)
plt.ylabel('Goals scored', fontsize = 14)

plt.savefig(r'C:\Users\Dask\Documents\Code\dsi\capstone\capstone\Figures\league_goals_hist.jpg');

# %% [markdown]
# ### Total Home/Away win data for the entire league by year

# %%
# Data for league-wide 'undefeated(wins+draws)' as a percentage of games played at home for each year

tot_home_yearly = pd.Series(
    [((df_13_14['HomeWin'].sum() + df_13_14['HomeDraw'].sum())/ df_13_14['HomePlayed'].sum())*100,
    ((df_14_15['HomeWin'].sum() + df_14_15['HomeDraw'].sum())/ df_14_15['HomePlayed'].sum())*100,
    ((df_15_16['HomeWin'].sum() + df_15_16['HomeDraw'].sum())/ df_15_16['HomePlayed'].sum())*100,
    ((df_16_17['HomeWin'].sum() + df_16_17['HomeDraw'].sum())/ df_16_17['HomePlayed'].sum())*100,
    ((df_17_18['HomeWin'].sum() + df_17_18['HomeDraw'].sum())/ df_17_18['HomePlayed'].sum())*100,
    ((df_18_19['HomeWin'].sum() + df_18_19['HomeDraw'].sum())/ df_18_19['HomePlayed'].sum())*100,
    ((df_19_20['HomeWin'].sum() + df_19_20['HomeDraw'].sum())/ df_19_20['HomePlayed'].sum())*100,
    ((df_20_21['HomeWin'].sum() + df_20_21['HomeDraw'].sum())/ df_20_21['HomePlayed'].sum())*100,
    ((df_21_22['HomeWin'].sum() + df_21_22['HomeDraw'].sum())/ df_21_22['HomePlayed'].sum())*100,
    ], index = [0, 1, 2, 3, 4, 5, 6, 7, 8])

# %%
# Data for league-wide 'undefeated(wins+draws)' as a percentage of games played away for each year

tot_away_yearly = pd.Series(
    [((df_13_14['AwayWin'].sum() + df_13_14['AwayDraw'].sum())/ df_13_14['AwayPlayed'].sum())*100,
    ((df_14_15['AwayWin'].sum() + df_14_15['AwayDraw'].sum())/ df_14_15['AwayPlayed'].sum())*100,
    ((df_15_16['AwayWin'].sum() + df_15_16['AwayDraw'].sum())/ df_15_16['AwayPlayed'].sum())*100,
    ((df_16_17['AwayWin'].sum() + df_16_17['AwayDraw'].sum())/ df_16_17['AwayPlayed'].sum())*100,
    ((df_17_18['AwayWin'].sum() + df_17_18['AwayDraw'].sum())/ df_17_18['AwayPlayed'].sum())*100,
    ((df_18_19['AwayWin'].sum() + df_18_19['AwayDraw'].sum())/ df_18_19['AwayPlayed'].sum())*100,
    ((df_19_20['AwayWin'].sum() + df_19_20['AwayDraw'].sum())/ df_19_20['AwayPlayed'].sum())*100,
    ((df_20_21['AwayWin'].sum() + df_20_21['AwayDraw'].sum())/ df_20_21['AwayPlayed'].sum())*100,
    ((df_21_22['AwayWin'].sum() + df_21_22['AwayDraw'].sum())/ df_21_22['AwayPlayed'].sum())*100,
    ], index = [0, 1, 2, 3, 4, 5, 6, 7, 8])

# %%
# Data for league-wide 'undefeated(wins+draws)' at home compared to total games played for each year

tot_yearly = pd.Series(
    [((df_13_14['HomeWin'].sum() + df_13_14['HomeDraw'].sum()) / (df_13_14['HomePlayed'].sum()+df_13_14['AwayPlayed'].sum()))*100,
    ((df_14_15['HomeWin'].sum() + df_14_15['HomeDraw'].sum())/ (df_14_15['HomePlayed'].sum()+df_14_15['AwayPlayed'].sum()))*100,
    ((df_15_16['HomeWin'].sum() + df_15_16['HomeDraw'].sum())/ (df_15_16['HomePlayed'].sum()+df_15_16['AwayPlayed'].sum()))*100,
    ((df_16_17['HomeWin'].sum() + df_16_17['HomeDraw'].sum())/ (df_16_17['HomePlayed'].sum()+df_16_17['AwayPlayed'].sum()))*100,
    ((df_17_18['HomeWin'].sum() + df_17_18['HomeDraw'].sum())/ (df_17_18['HomePlayed'].sum()+df_17_18['AwayPlayed'].sum()))*100,
    ((df_18_19['HomeWin'].sum() + df_18_19['HomeDraw'].sum())/ (df_18_19['HomePlayed'].sum()+df_18_19['AwayPlayed'].sum()))*100,
    ((df_19_20['HomeWin'].sum() + df_19_20['HomeDraw'].sum())/ (df_19_20['HomePlayed'].sum()+df_19_20['AwayPlayed'].sum()))*100,
    ((df_20_21['HomeWin'].sum() + df_20_21['HomeDraw'].sum())/ (df_20_21['HomePlayed'].sum()+df_20_21['AwayPlayed'].sum()))*100,
    ((df_21_22['HomeWin'].sum() + df_21_22['HomeDraw'].sum())/ (df_21_22['HomePlayed'].sum()+df_21_22['AwayPlayed'].sum()))*100,
    ], index = [0, 1, 2, 3, 4, 5, 6, 7, 8])

# %%
# Line graph of Home undefeatedness over home games played, away undefeatedness over away games played, and home undefeatedness over total games played per year

x = 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021
plt.figure(figsize=(14,10), dpi = 100)

plt.plot(x, tot_home_yearly, color = 'blue', label = 'Home undefeated % of Home Played', linewidth = 4)
plt.plot(x, tot_away_yearly, color = 'red', label = 'Away undefeated % of Away Played', linewidth = 4)
plt.plot(x, tot_yearly, color = 'black', label = 'Home undefeated % of total games', linewidth = 4)
plt.yticks(ticks = range(25, 75, 5), labels = range(25, 75, 5))
plt.legend()
plt.title('% of games undefeated at home and away for the entire league per year', fontsize = 18)
plt.xlabel('Year', fontsize = 14)
plt.ylabel('Game % won', fontsize = 14)

plt.savefig(r'C:\Users\Dask\Documents\Code\dsi\capstone\capstone\Figures\league_games_bar.jpg');

# %%
# Data for Liverpool's performance (wins+draws) at home compared to games played at home for each year

liv_home = pd.Series([
    (df_13_14.loc[df_13_14['TeamName'] == 'Liverpool', 'HomeWin'] + df_13_14.loc[df_13_14['TeamName'] == 'Liverpool', 'HomeDraw'])/ df_13_14.loc[df_13_14['TeamName'] == 'Liverpool', 'HomePlayed']*100,
    (df_14_15.loc[df_14_15['TeamName'] == 'Liverpool', 'HomeWin'] + df_14_15.loc[df_14_15['TeamName'] == 'Liverpool', 'HomeDraw'])/ df_14_15.loc[df_14_15['TeamName'] == 'Liverpool', 'HomePlayed']*100,
    (df_15_16.loc[df_15_16['TeamName'] == 'Liverpool', 'HomeWin'] + df_15_16.loc[df_15_16['TeamName'] == 'Liverpool', 'HomeDraw'])/ df_15_16.loc[df_15_16['TeamName'] == 'Liverpool', 'HomePlayed']*100,
    (df_16_17.loc[df_16_17['TeamName'] == 'Liverpool', 'HomeWin'] + df_16_17.loc[df_16_17['TeamName'] == 'Liverpool', 'HomeDraw'])/ df_16_17.loc[df_16_17['TeamName'] == 'Liverpool', 'HomePlayed']*100,
    (df_17_18.loc[df_17_18['TeamName'] == 'Liverpool', 'HomeWin'] + df_17_18.loc[df_17_18['TeamName'] == 'Liverpool', 'HomeDraw'])/ df_17_18.loc[df_17_18['TeamName'] == 'Liverpool', 'HomePlayed']*100,
    (df_18_19.loc[df_18_19['TeamName'] == 'Liverpool', 'HomeWin'] + df_18_19.loc[df_18_19['TeamName'] == 'Liverpool', 'HomeDraw'])/ df_18_19.loc[df_18_19['TeamName'] == 'Liverpool', 'HomePlayed']*100,
    (df_19_20.loc[df_19_20['TeamName'] == 'Liverpool', 'HomeWin'] + df_19_20.loc[df_19_20['TeamName'] == 'Liverpool', 'HomeDraw'])/ df_19_20.loc[df_19_20['TeamName'] == 'Liverpool', 'HomePlayed']*100,
    (df_20_21.loc[df_20_21['TeamName'] == 'Liverpool', 'HomeWin'] + df_20_21.loc[df_20_21['TeamName'] == 'Liverpool', 'HomeDraw'])/ df_20_21.loc[df_20_21['TeamName'] == 'Liverpool', 'HomePlayed']*100,
    (df_21_22.loc[df_21_22['TeamName'] == 'Liverpool', 'HomeWin'] + df_21_22.loc[df_21_22['TeamName'] == 'Liverpool', 'HomeDraw'])/ df_21_22.loc[df_21_22['TeamName'] == 'Liverpool', 'HomePlayed']*100,
          ], index = [0, 1, 2, 3, 4, 5, 6, 7, 8])

# %%
# Data for Liverpool's performance (wins+draws) away compared to games played away for each year

liv_away = pd.Series([
    (df_13_14.loc[df_13_14['TeamName'] == 'Liverpool', 'AwayWin'] + df_13_14.loc[df_13_14['TeamName'] == 'Liverpool', 'AwayDraw'])/ df_13_14.loc[df_13_14['TeamName'] == 'Liverpool', 'AwayPlayed']*100,
    (df_14_15.loc[df_14_15['TeamName'] == 'Liverpool', 'AwayWin'] + df_14_15.loc[df_14_15['TeamName'] == 'Liverpool', 'AwayDraw'])/ df_14_15.loc[df_14_15['TeamName'] == 'Liverpool', 'AwayPlayed']*100,
    (df_15_16.loc[df_15_16['TeamName'] == 'Liverpool', 'AwayWin'] + df_15_16.loc[df_15_16['TeamName'] == 'Liverpool', 'AwayDraw'])/ df_15_16.loc[df_15_16['TeamName'] == 'Liverpool', 'AwayPlayed']*100,
    (df_16_17.loc[df_16_17['TeamName'] == 'Liverpool', 'AwayWin'] + df_16_17.loc[df_16_17['TeamName'] == 'Liverpool', 'AwayDraw'])/ df_16_17.loc[df_16_17['TeamName'] == 'Liverpool', 'AwayPlayed']*100,
    (df_17_18.loc[df_17_18['TeamName'] == 'Liverpool', 'AwayWin'] + df_17_18.loc[df_17_18['TeamName'] == 'Liverpool', 'AwayDraw'])/ df_17_18.loc[df_17_18['TeamName'] == 'Liverpool', 'AwayPlayed']*100,
    (df_18_19.loc[df_18_19['TeamName'] == 'Liverpool', 'AwayWin'] + df_18_19.loc[df_18_19['TeamName'] == 'Liverpool', 'AwayDraw'])/ df_18_19.loc[df_18_19['TeamName'] == 'Liverpool', 'AwayPlayed']*100,
    (df_19_20.loc[df_19_20['TeamName'] == 'Liverpool', 'AwayWin'] + df_19_20.loc[df_19_20['TeamName'] == 'Liverpool', 'AwayDraw'])/ df_19_20.loc[df_19_20['TeamName'] == 'Liverpool', 'AwayPlayed']*100,
    (df_20_21.loc[df_20_21['TeamName'] == 'Liverpool', 'AwayWin'] + df_20_21.loc[df_20_21['TeamName'] == 'Liverpool', 'AwayDraw'])/ df_20_21.loc[df_20_21['TeamName'] == 'Liverpool', 'AwayPlayed']*100,
    (df_21_22.loc[df_21_22['TeamName'] == 'Liverpool', 'AwayWin'] + df_21_22.loc[df_21_22['TeamName'] == 'Liverpool', 'AwayDraw'])/ df_21_22.loc[df_21_22['TeamName'] == 'Liverpool', 'AwayPlayed']*100,
          ], index = [0, 1, 2, 3, 4, 5, 6, 7, 8])

# %%
# Data for Liverpool's performance (wins+draws) at home compared to games played in total for each year

liv_tot = pd.Series([
    (df_13_14.loc[df_13_14['TeamName'] == 'Liverpool', 'HomeWin'] + df_13_14.loc[df_13_14['TeamName'] == 'Liverpool', 'HomeDraw']) / (df_13_14.loc[df_13_14['TeamName'] == 'Liverpool', 'HomePlayed'] + df_13_14.loc[df_13_14['TeamName'] == 'Liverpool', 'AwayPlayed'])*100,
    (df_14_15.loc[df_14_15['TeamName'] == 'Liverpool', 'HomeWin'] + df_14_15.loc[df_14_15['TeamName'] == 'Liverpool', 'HomeDraw']) / (df_14_15.loc[df_14_15['TeamName'] == 'Liverpool', 'HomePlayed'] + df_14_15.loc[df_14_15['TeamName'] == 'Liverpool', 'AwayPlayed'])*100,
    (df_15_16.loc[df_15_16['TeamName'] == 'Liverpool', 'HomeWin'] + df_15_16.loc[df_15_16['TeamName'] == 'Liverpool', 'HomeDraw']) / (df_15_16.loc[df_15_16['TeamName'] == 'Liverpool', 'HomePlayed'] + df_15_16.loc[df_15_16['TeamName'] == 'Liverpool', 'AwayPlayed'])*100,
    (df_16_17.loc[df_16_17['TeamName'] == 'Liverpool', 'HomeWin'] + df_16_17.loc[df_16_17['TeamName'] == 'Liverpool', 'HomeDraw']) / (df_16_17.loc[df_16_17['TeamName'] == 'Liverpool', 'HomePlayed'] + df_16_17.loc[df_16_17['TeamName'] == 'Liverpool', 'AwayPlayed'])*100,
    (df_17_18.loc[df_17_18['TeamName'] == 'Liverpool', 'HomeWin'] + df_17_18.loc[df_17_18['TeamName'] == 'Liverpool', 'HomeDraw']) / (df_17_18.loc[df_17_18['TeamName'] == 'Liverpool', 'HomePlayed'] + df_17_18.loc[df_17_18['TeamName'] == 'Liverpool', 'AwayPlayed'])*100,
    (df_18_19.loc[df_18_19['TeamName'] == 'Liverpool', 'HomeWin'] + df_18_19.loc[df_18_19['TeamName'] == 'Liverpool', 'HomeDraw']) / (df_18_19.loc[df_18_19['TeamName'] == 'Liverpool', 'HomePlayed'] + df_18_19.loc[df_18_19['TeamName'] == 'Liverpool', 'AwayPlayed'])*100,
    (df_19_20.loc[df_19_20['TeamName'] == 'Liverpool', 'HomeWin'] + df_19_20.loc[df_19_20['TeamName'] == 'Liverpool', 'HomeDraw']) / (df_19_20.loc[df_19_20['TeamName'] == 'Liverpool', 'HomePlayed'] + df_19_20.loc[df_19_20['TeamName'] == 'Liverpool', 'AwayPlayed'])*100,
    (df_20_21.loc[df_20_21['TeamName'] == 'Liverpool', 'HomeWin'] + df_20_21.loc[df_20_21['TeamName'] == 'Liverpool', 'HomeDraw']) / (df_20_21.loc[df_20_21['TeamName'] == 'Liverpool', 'HomePlayed'] + df_20_21.loc[df_20_21['TeamName'] == 'Liverpool', 'AwayPlayed'])*100,
    (df_21_22.loc[df_21_22['TeamName'] == 'Liverpool', 'HomeWin'] + df_21_22.loc[df_21_22['TeamName'] == 'Liverpool', 'HomeDraw']) / (df_21_22.loc[df_21_22['TeamName'] == 'Liverpool', 'HomePlayed'] + df_21_22.loc[df_21_22['TeamName'] == 'Liverpool', 'AwayPlayed'])*100,
          ], index = [0, 1, 2, 3, 4, 5, 6, 7, 8])

# %%
# Line graph of Liverpool's Home undefeatedness over home games played, away undefeatedness over away games played, and home undefeatedness over total games played per year

x = 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021
plt.figure(figsize=(14,10), dpi = 100)

plt.plot(x, liv_home, color = 'blue', label = 'Home Undefeated % of Home Played', linewidth = 4)
plt.plot(x, liv_away, color = 'red', label = 'Away Undefeated % of Away Played', linewidth = 4)
plt.plot(x, liv_tot, color = 'black', label = 'Home Undefeated % of total games', linewidth = 4)
plt.yticks(ticks = range(20, 101, 5), labels = range(20, 101, 5))
plt.legend()
plt.title('% of games undefeated by Liverpool at home and away for the entire league per year', fontsize = 18)
plt.xlabel('Year', fontsize = 14)
plt.ylabel('Game % won', fontsize = 14)

plt.savefig(r'C:\Users\Dask\Documents\Code\dsi\capstone\capstone\Figures\liv_games_bar.jpg');

# %%
# Line graph of Liverpool's Home undefeatedness over home games played, away undefeatedness over away games played, and home undefeatedness over total games played per year

x = 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021
plt.figure(figsize=(14,10), dpi = 100)

plt.plot(x, liv_home, color = 'blue', label = 'Home Undefeated % of Home Played', linewidth = 4)
plt.plot(x, liv_away, color = 'red', label = 'Away Undefeated % of Away Played', linewidth = 4)
plt.plot(x, liv_tot, color = 'black', label = 'Home Undefeated % of total games', linewidth = 4)
plt.axhline(90,linewidth=3, color='blue', linestyle = 'dashed')
plt.axhline(72,linewidth=3, color='red', linestyle = 'dashed')
plt.yticks(ticks = range(20, 101, 5), labels = range(20, 101, 5))
plt.legend()
plt.title('% of games undefeated by Liverpool at home and away for the entire league per year', fontsize = 18)
plt.xlabel('Year', fontsize = 14)
plt.ylabel('Game % won', fontsize = 14)

plt.savefig(r'C:\Users\Dask\Documents\Code\dsi\capstone\capstone\Figures\liv_games_bar_with_baseline.jpg');
